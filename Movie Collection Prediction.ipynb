# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

# %%
data_x=pd.read_csv('D:/DEEP LEARNING INTERNSHALA/Assignment DS/Assignment_4_data/Movie_collection_Independent.csv')

# %%
data_y=pd.read_csv('D:/DEEP LEARNING INTERNSHALA/Assignment DS/Assignment_4_data/Movie_collection_Target.csv')

# %%
data_x.head(5)
# Out:
#    Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0           20.1264               59.62               0.462  36524.125
# 1           20.5462               69.14               0.531  35668.655
# 2           20.5458               69.14               0.531  39912.675
# 3           20.6474               59.36               0.542  38873.890
# 4           21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
data_x.describe()
# Out:
#        Marketin_expense  Production_expense  Multiplex_coverage        Budget  \
# count        506.000000          506.000000          506.000000    506.000000
# mean          92.270471           77.273557            0.445305  34911.144022
# std          172.030902           13.720706            0.115878   3903.038232
# min           20.126400           55.920000            0.129000  19781.355000
# 25%           21.640900           65.380000            0.376000  32693.952500
# 50%           25.130200           74.380000            0.462000  34488.217500
# 75%           93.541650           91.200000            0.551000  36793.542500
# max         1799.524000          110.480000            0.615000  48772.900000
#
#        Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# count    506.000000          506.000000           506.000000       506.000000
# mean     142.074901            8.014002             8.185613         8.019664
# ...

# %%
data_y.head(5)
# Out:
#    Collection
# 0    2.266667
# 1    2.106667
# 2    2.980000
# 3    2.893333
# 4    3.080000

# %%
data_y.describe()
# Out:
#        Collection
# count  506.000000
# mean     2.168590
# std      0.612145
# min      1.000000
# 25%      1.801667
# 50%      2.080000
# 75%      2.333333
# max      4.000000

# %%
data_x.shape
# Out:
# (506, 19)

# %%
data_y.shape
# Out:
# (506, 1)

# %%
from sklearn.model_selection import train_test_split
X_train_full,X_test,y_train_full,y_test=train_test_split(data_x,data_y,random_state=42)
X_train,X_valid,y_train,y_valid=train_test_split(X_train_full,y_train_full,random_state=42)

# %%
X_train.shape
# Out:
# (284, 19)

# %%
y_train.shape
# Out:
# (284, 1)

# %%
X_valid.shape
# Out:
# (95, 19)

# %%
y_valid.shape
# Out:
# (95, 1)

# %%
X_test.shape
# Out:
# (127, 19)

# %%
y_test.shape
# Out:
# (127, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_valid=scaler.transform(X_valid)
X_test=scaler.transform(X_test)

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
model=keras.models.Sequential([
    keras.layers.Dense(30,activation="relu",input_shape=[19]),
    keras.layers.Dense(30,activation="relu"),
    keras.layers.Dense(1)
])

# %%
model.summary()
model.compile(loss="mean_squared_error",
            optimizer=keras.optimizers.SGD(lr=1e-2),
            metrics=['mae'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 30)                600
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# ...
# Total params: 1,561
# Trainable params: 1,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(X_train,y_train,epochs=100,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/100
# 9/9 [==============================] - 0s 29ms/step - loss: 3.7051 - mae: 1.6837 - val_loss: 1.5134 - val_mae: 1.0270
# Epoch 2/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8049 - mae: 0.7017 - val_loss: 0.7741 - val_mae: 0.6938
# Epoch 3/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5344 - mae: 0.5752 - val_loss: 0.5643 - val_mae: 0.5909
# Epoch 4/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4031 - mae: 0.4938 - val_loss: 0.4334 - val_mae: 0.5210
# Epoch 5/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3196 - mae: 0.4360 - val_loss: 0.3577 - val_mae: 0.4742
# Epoch 6/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2654 - mae: 0.3940 - val_loss: 0.3054 - val_mae: 0.4403
# Epoch 7/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2292 - mae: 0.3646 - val_loss: 0.2627 - val_mae: 0.4063
# Epoch 8/100
# ...

# %%
mae_test=model.evaluate(X_test,y_test)
# Out:
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2852 - mae: 0.2786

# %%
model_history.history
# Out:
# {'loss': [3.7051382064819336,
#   0.8049361705780029,
#   0.5343937277793884,
#   0.4030892848968506,
#   0.3196466863155365,
#   0.2654058039188385,
#   0.22918854653835297,
#   0.2027868628501892,
#   0.18602554500102997,
#   0.17118272185325623,
#   0.15834027528762817,
#   0.1506919115781784,
#   0.14323686063289642,
#   0.13740918040275574,
#   0.13083124160766602,
#   0.12692905962467194,
#   0.12337269634008408,
#   0.11972310394048691,
#   0.11679045110940933,
#   0.11306770890951157,
#   0.11098860204219818,
#   0.10840646922588348,
#   0.10606019198894501,
#   0.10412035882472992,
#   0.10202548652887344,
#   0.10033942759037018,
#   0.09871717542409897,
#   0.09766827523708344,
#   0.09514549374580383,
#   0.0941467434167862,
#   0.09169479459524155,
#   0.09133154898881912,
#   0.0895605981349945,
#   0.08890088647603989,
#   0.08721437305212021,
#   0.08587536215782166,
#   0.0849984809756279,
#   0.08360110223293304,
#   0.08260928094387054,
#   0.08193270862102509,
# ...

# %%
pd.DataFrame(model_history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)

plt.show()

# %%
X_new=X_test[:5]

# %%
y_pred=model.predict(X_new)
print(y_pred)
print(y_test[:5])
# Out:
# [[2.5145755]
#  [2.6631563]
#  [1.8457   ]
#  [2.4707603]
#  [1.7309108]]
#      Collection
# 173    2.240000
# 274    2.826667
# 491    1.573333
# 72     2.186667
# 452    1.740000

# %%
model.save("movie_collection.h5")
